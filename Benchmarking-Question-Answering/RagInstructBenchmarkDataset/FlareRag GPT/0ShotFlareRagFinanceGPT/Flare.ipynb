# %%
from langchain.document_loaders import DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.storage import (
    LocalFileStore,
)
from langchain.embeddings import CacheBackedEmbeddings, HuggingFaceEmbeddings
from transformers import T5Tokenizer, T5ForConditionalGeneration
import torch

import pandas as pd

from datasets import load_dataset
 
#import openai

# %%
dataset = load_dataset("llmware/rag_instruct_benchmark_tester")

# %%
df = pd.DataFrame(dataset['train'])

# %%
import os

# Assuming df is your DataFrame
for index, row in df.iterrows():
    evidence_text = row['context']
    # Define the filename based on the index or any other identifier
    filename = f"text_{index}.txt"
    # Specify the directory where you want to save the .txt files
    directory = "txt"
    # If the directory doesn't exist, create it
    if not os.path.exists(directory):
        os.makedirs(directory)
    # Combine the directory and filename to create the full path
    filepath = os.path.join(directory, filename)
    
    # Write the evidence_text to the .txt file
    with open(filepath, 'w') as file:
        file.write(evidence_text)

    print(f"Text for index {index} stored in {filepath}")
# Out:
# Text for index 0 stored in txt\text_0.txt
# Text for index 1 stored in txt\text_1.txt
# Text for index 2 stored in txt\text_2.txt
# Text for index 3 stored in txt\text_3.txt
# Text for index 4 stored in txt\text_4.txt
# Text for index 5 stored in txt\text_5.txt
# Text for index 6 stored in txt\text_6.txt
# Text for index 7 stored in txt\text_7.txt
# Text for index 8 stored in txt\text_8.txt
# Text for index 9 stored in txt\text_9.txt
# Text for index 10 stored in txt\text_10.txt
# Text for index 11 stored in txt\text_11.txt
# Text for index 12 stored in txt\text_12.txt
# Text for index 13 stored in txt\text_13.txt
# Text for index 14 stored in txt\text_14.txt
# Text for index 15 stored in txt\text_15.txt
# Text for index 16 stored in txt\text_16.txt
# Text for index 17 stored in txt\text_17.txt
# Text for index 18 stored in txt\text_18.txt
# Text for index 19 stored in txt\text_19.txt
# Text for index 20 stored in txt\text_20.txt
# Text for index 21 stored in txt\text_21.txt
# Text for index 22 stored in txt\text_22.txt
# Text for index 23 stored in txt\text_23.txt
# Text for index 24 stored in txt\text_24.txt
# Text for index 25 stored in txt\text_25.txt
# Text for index 26 stored in txt\text_26.txt
# Text for index 27 stored in txt\text_27.txt
# Text for index 28 stored in txt\text_28.txt
# Text for index 29 stored in txt\text_29.txt
# Text for index 30 stored in txt\text_30.txt
# Text for index 31 stored in txt\text_31.txt
# Text for index 32 stored in txt\text_32.txt
# Text for index 33 stored in txt\text_33.txt
# Text for index 34 stored in txt\text_34.txt
# Text for index 35 stored in txt\text_35.txt
# Text for index 36 stored in txt\text_36.txt
# Text for index 37 stored in txt\text_37.txt
# Text for index 38 stored in txt\text_38.txt
# Text for index 39 stored in txt\text_39.txt
# Text for index 40 stored in txt\text_40.txt
# Text for index 41 stored in txt\text_41.txt
# Text for index 42 stored in txt\text_42.txt
# Text for index 43 stored in txt\text_43.txt
# Text for index 44 stored in txt\text_44.txt
# Text for index 45 stored in txt\text_45.txt
# Text for index 46 stored in txt\text_46.txt
# Text for index 47 stored in txt\text_47.txt
# Text for index 48 stored in txt\text_48.txt
# Text for index 49 stored in txt\text_49.txt
# Text for index 50 stored in txt\text_50.txt
# Text for index 51 stored in txt\text_51.txt
# Text for index 52 stored in txt\text_52.txt
# Text for index 53 stored in txt\text_53.txt
# Text for index 54 stored in txt\text_54.txt
# Text for index 55 stored in txt\text_55.txt
# Text for index 56 stored in txt\text_56.txt
# Text for index 57 stored in txt\text_57.txt
# Text for index 58 stored in txt\text_58.txt
# Text for index 59 stored in txt\text_59.txt
# Text for index 60 stored in txt\text_60.txt
# Text for index 61 stored in txt\text_61.txt
# Text for index 62 stored in txt\text_62.txt
# Text for index 63 stored in txt\text_63.txt
# Text for index 64 stored in txt\text_64.txt
# Text for index 65 stored in txt\text_65.txt
# Text for index 66 stored in txt\text_66.txt
# Text for index 67 stored in txt\text_67.txt
# Text for index 68 stored in txt\text_68.txt
# Text for index 69 stored in txt\text_69.txt
# Text for index 70 stored in txt\text_70.txt
# Text for index 71 stored in txt\text_71.txt
# Text for index 72 stored in txt\text_72.txt
# Text for index 73 stored in txt\text_73.txt
# Text for index 74 stored in txt\text_74.txt
# Text for index 75 stored in txt\text_75.txt
# Text for index 76 stored in txt\text_76.txt
# Text for index 77 stored in txt\text_77.txt
# Text for index 78 stored in txt\text_78.txt
# Text for index 79 stored in txt\text_79.txt
# Text for index 80 stored in txt\text_80.txt
# Text for index 81 stored in txt\text_81.txt
# Text for index 82 stored in txt\text_82.txt
# Text for index 83 stored in txt\text_83.txt
# Text for index 84 stored in txt\text_84.txt
# Text for index 85 stored in txt\text_85.txt
# Text for index 86 stored in txt\text_86.txt
# Text for index 87 stored in txt\text_87.txt
# Text for index 88 stored in txt\text_88.txt
# Text for index 89 stored in txt\text_89.txt
# Text for index 90 stored in txt\text_90.txt
# Text for index 91 stored in txt\text_91.txt
# Text for index 92 stored in txt\text_92.txt
# Text for index 93 stored in txt\text_93.txt
# Text for index 94 stored in txt\text_94.txt
# Text for index 95 stored in txt\text_95.txt
# Text for index 96 stored in txt\text_96.txt
# Text for index 97 stored in txt\text_97.txt
# Text for index 98 stored in txt\text_98.txt
# Text for index 99 stored in txt\text_99.txt
# Text for index 100 stored in txt\text_100.txt
# Text for index 101 stored in txt\text_101.txt
# Text for index 102 stored in txt\text_102.txt
# Text for index 103 stored in txt\text_103.txt
# Text for index 104 stored in txt\text_104.txt
# Text for index 105 stored in txt\text_105.txt
# Text for index 106 stored in txt\text_106.txt
# Text for index 107 stored in txt\text_107.txt
# Text for index 108 stored in txt\text_108.txt
# Text for index 109 stored in txt\text_109.txt
# Text for index 110 stored in txt\text_110.txt
# Text for index 111 stored in txt\text_111.txt
# Text for index 112 stored in txt\text_112.txt
# Text for index 113 stored in txt\text_113.txt
# Text for index 114 stored in txt\text_114.txt
# Text for index 115 stored in txt\text_115.txt
# Text for index 116 stored in txt\text_116.txt
# Text for index 117 stored in txt\text_117.txt
# Text for index 118 stored in txt\text_118.txt
# Text for index 119 stored in txt\text_119.txt
# Text for index 120 stored in txt\text_120.txt
# Text for index 121 stored in txt\text_121.txt
# Text for index 122 stored in txt\text_122.txt
# Text for index 123 stored in txt\text_123.txt
# Text for index 124 stored in txt\text_124.txt
# Text for index 125 stored in txt\text_125.txt
# Text for index 126 stored in txt\text_126.txt
# Text for index 127 stored in txt\text_127.txt
# Text for index 128 stored in txt\text_128.txt
# Text for index 129 stored in txt\text_129.txt
# Text for index 130 stored in txt\text_130.txt
# Text for index 131 stored in txt\text_131.txt
# Text for index 132 stored in txt\text_132.txt
# Text for index 133 stored in txt\text_133.txt
# Text for index 134 stored in txt\text_134.txt
# Text for index 135 stored in txt\text_135.txt
# Text for index 136 stored in txt\text_136.txt
# Text for index 137 stored in txt\text_137.txt
# Text for index 138 stored in txt\text_138.txt
# Text for index 139 stored in txt\text_139.txt
# Text for index 140 stored in txt\text_140.txt
# Text for index 141 stored in txt\text_141.txt
# Text for index 142 stored in txt\text_142.txt
# Text for index 143 stored in txt\text_143.txt
# Text for index 144 stored in txt\text_144.txt
# Text for index 145 stored in txt\text_145.txt
# Text for index 146 stored in txt\text_146.txt
# Text for index 147 stored in txt\text_147.txt
# Text for index 148 stored in txt\text_148.txt
# Text for index 149 stored in txt\text_149.txt
# Text for index 150 stored in txt\text_150.txt
# Text for index 151 stored in txt\text_151.txt
# Text for index 152 stored in txt\text_152.txt
# Text for index 153 stored in txt\text_153.txt
# Text for index 154 stored in txt\text_154.txt
# Text for index 155 stored in txt\text_155.txt
# Text for index 156 stored in txt\text_156.txt
# Text for index 157 stored in txt\text_157.txt
# Text for index 158 stored in txt\text_158.txt
# Text for index 159 stored in txt\text_159.txt
# Text for index 160 stored in txt\text_160.txt
# Text for index 161 stored in txt\text_161.txt
# Text for index 162 stored in txt\text_162.txt
# Text for index 163 stored in txt\text_163.txt
# Text for index 164 stored in txt\text_164.txt
# Text for index 165 stored in txt\text_165.txt
# Text for index 166 stored in txt\text_166.txt
# Text for index 167 stored in txt\text_167.txt
# Text for index 168 stored in txt\text_168.txt
# Text for index 169 stored in txt\text_169.txt
# Text for index 170 stored in txt\text_170.txt
# Text for index 171 stored in txt\text_171.txt
# Text for index 172 stored in txt\text_172.txt
# Text for index 173 stored in txt\text_173.txt
# Text for index 174 stored in txt\text_174.txt
# Text for index 175 stored in txt\text_175.txt
# Text for index 176 stored in txt\text_176.txt
# Text for index 177 stored in txt\text_177.txt
# Text for index 178 stored in txt\text_178.txt
# Text for index 179 stored in txt\text_179.txt
# Text for index 180 stored in txt\text_180.txt
# Text for index 181 stored in txt\text_181.txt
# Text for index 182 stored in txt\text_182.txt
# Text for index 183 stored in txt\text_183.txt
# Text for index 184 stored in txt\text_184.txt
# Text for index 185 stored in txt\text_185.txt
# Text for index 186 stored in txt\text_186.txt
# Text for index 187 stored in txt\text_187.txt
# Text for index 188 stored in txt\text_188.txt
# Text for index 189 stored in txt\text_189.txt
# Text for index 190 stored in txt\text_190.txt
# Text for index 191 stored in txt\text_191.txt
# Text for index 192 stored in txt\text_192.txt
# Text for index 193 stored in txt\text_193.txt
# Text for index 194 stored in txt\text_194.txt
# Text for index 195 stored in txt\text_195.txt
# Text for index 196 stored in txt\text_196.txt
# Text for index 197 stored in txt\text_197.txt
# Text for index 198 stored in txt\text_198.txt
# Text for index 199 stored in txt\text_199.txt

# %%
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.chains import FlareChain
from langchain.llms import OpenAI

# %%
import os

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
def create_vector_db(embedding_model='text-embedding-ada-002',data_path='txt/'):
    # Load all the transcripts stored in the data folder
    loader = DirectoryLoader(data_path, glob="**/*.txt", show_progress=True)
    docs = loader.load()

    # Split the documents into smaller chunks
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=900, chunk_overlap=50)
    documents = text_splitter.split_documents(docs)

    # Initialize OpenAI Embeddings
    openai_embedder = OpenAIEmbeddings(model=embedding_model)

    # Cache the embeddings for faster loadup
    cache_store = LocalFileStore("./cache/")
    cached_embedder = CacheBackedEmbeddings.from_bytes_store(openai_embedder, cache_store, namespace="sentence")

    # Create the vector db
    db = FAISS.from_documents(documents, cached_embedder)
    return db

# %%
db = create_vector_db()
# Out:
# 100%|██████████| 200/200 [00:02<00:00, 99.81it/s]

# %%
from langchain_community.chat_models import ChatOpenAI

# %%
myllm = ChatOpenAI(temperature=0.30, model_name="gpt-3.5-turbo-16k")

flare = FlareChain.from_llm(
    llm=myllm,
    retriever=db.as_retriever(),
    max_generation_len=700,
    min_prob=0.25,   
    instruction = 'You are a factual chatbot that answers questions about for giving text. You only answer with answers you find in the text, no outside information.'  
    )

# %%
result = flare.run(df['query'][0])

# %%
result
# Out:
# 'The total amount of the invoice is $500. '

# %%
df
# Out:
#                                                  query  \
# 0             What is the total amount of the invoice?
# 1                          What is the invoice number?
# 2         What is a list of the items being purchased?
# 3        What is the name of the contact for question?
# 4                               What is the PO number?
# ..                                                 ...
# 195                        What is a one-line summary?
# 196  What is a list of the executive's responsibili...
# 197                    What is a headline description?
# 198  What is a summary of the CEO's statement in 15...
# 199             What are the key terms of the invoice?
#
#                                                 answer  \
# 0                                           $22,500.00
# 1                                                #0001
# 2    •Front End Engineering Service;\n•Back End Eng...
# 3                                           Bia Hermes
# 4                                                #1000
# ..                                                 ...
# 195  Nokia is cutting 14,000 jobs as part of a cost...
# 196  •Senior Vice President, Event Planning ('SVP')...
# 197  NVIDIA Announces Second Quarter Fiscal 2024 Re...
# 198  Microsoft Cloud is the platform of choice for ...
# 199  •Invoice From: Services Vendor Inc.;\n•Invoice...
#
#                                                context  sample_number  tokens  \
# 0    Services Vendor Inc. \n100 Elm Street Pleasant...              0     138
# 1    Services Vendor Inc. \n100 Elm Street Pleasant...              1     138
# 2    Services Vendor Inc. \n100 Elm Street Pleasant...              2     138
# 3    Services Vendor Inc. \n100 Elm Street Pleasant...              3     138
# 4    Services Vendor Inc. \n100 Elm Street Pleasant...              4     138
# ..                                                 ...            ...     ...
# 195  Nokia said it would cut up to 14,000 jobs as p...            195      96
# 196  2.1. Duties and Responsibilities and Extent of...            196     340
# 197  NVIDIA Announces Financial Results for Second ...            197     428
# 198  'The world's most advanced AI models are comin...            198     137
# 199  Services Vendor Inc. \n100 Elm Street Pleasant...            199     138
#
#     category
# 0       core
# 1       core
# 2       core
# 3       core
# 4       core
# ..       ...
# 195  summary
# 196  summary
# 197  summary
# 198  summary
# 199  summary
#
# [200 rows x 6 columns]

# %%
results = []
for index, row in df.iterrows():
    result = flare.run(row['query'])
    print(index,result)
    results.append(result)
# Out:
# 0 The total amount of the invoice is $500.
# 1 The invoice number is a unique identifier for a specific invoice. It is typically located at the top of the invoice and is used for tracking and reference purposes. Do you have a specific invoice number in mind?
# 2 The items being purchased are Milk, Cheese, Chocolate, and Coffee.
# 3 The contact for any questions regarding this invoice is Bia Hermes.
# 4 The PO number for this invoice is 1000.
# 5 The payment is due on the date specified in your contract or invoice. If you are unsure, please refer to your contract or contact our customer service team for assistance.
# 6 The payment is due on the date specified in your contract or invoice. If you are unsure, please refer to your contract or contact our customer service team for assistance.
# 7 The subtotal amount is the total cost of all items before any taxes or discounts are applied.
# 8 The total amount can vary depending on the context. Can you provide more information so I can give you an accurate answer?
# 9 A list of the purchased items is a collection of all the items that have been bought or acquired by a person or organization. This can include groceries, clothing, electronics, furniture, and any other items that have been purchased. Is there a specific list of items you are looking for?
# 10 The invoice number is a unique identifier for a specific invoice. It is typically located at the top of the invoice and is used for tracking and reference purposes. Do you have a specific invoice number in mind?
# 11 The two companies mentioned are UTZ Brands (UTZ) and Kraft Heinz (KHC).
# 12 I'm sorry, I'm not sure what you're asking. This context is about sending notices to different companies. Can I help you with anything else?
#
#
# 13 The payment terms are due on receipt, with a due date of May 3, 2022.
#
#
# 14 The address of ABC Company is 123 Main Street.
# 15 The date of the invoice is March 3, 2022.
# 16 Biden was inaugurated on January 20, 2021.
# 17 Biden's opponent in the 2020 presidential election was Donald Trump.
# 18 Biden is from the state of Delaware.
# 19 The President when Biden was Vice President was Barack Obama.
# 20 The three people who served as co-chairs of the COVID task force were Dr. Deborah Birx, Dr. Anthony Fauci, and Dr. Robert Redfield.
# 21 The two people who won elections in Georgia are Jon Ossoff and Raphael Warnock.
# 22 Raphael Warnock's term is six years.
# 23 According to the Department of Defense, approximately 26,000 National Guard members were deployed on January 6 to assist with security during the presidential inauguration.
# 24 The letter of ascertainment was issued on [insert date here].
# 25 According to Microsoft's financial report, their revenue in the 3rd quarter was $33.1 billion.
# 26 I'm sorry, I cannot answer that question as it is not related to the context provided.  Can I assist you with anything else?
# 27 The quarter ended on December 31st.
# 28 The increase in cloud revenue was driven by growth in Azure and other cloud services, as well as an increase in Dynamics 365 revenue.
# 29 I'm sorry, I cannot provide specific financial information. However, I can tell you that our Cloud revenue has been steadily increasing over the past few quarters.
# 30 LinkedIn revenue increased 8% (up 10% in constant currency).
# 31 As of April 2021, Microsoft 365 has over 50 million consumer subscribers.
# 32 I'm sorry, I am not able to provide specific financial information. However, according to Microsoft's latest earnings report, Intelligent Cloud revenue increased by 27% in the last quarter. Is there anything else I can assist you with?
# 33 The field of AI was founded in the 1950s, but it gained significant attention and funding in the 1960s.
# 34 The Church-Turing thesis is a mathematical concept that states that any function that can be computed by an algorithm can also be computed by a Turing machine. This means that any problem that can be solved by a computer can also be solved by a Turing machine, which is a theoretical model of a computer. This thesis has had a significant impact on the development of computer science and has helped to shape our understanding of what is computable.
# 35 The first paper on AI was published in 1943 by McCullouch and Pitts.
# 36 The workshop at Dartmouth was held on [insert date here].
# 37 An AI winter is a period of time when obtaining funding for AI projects is difficult, often due to a lack of success or progress in the field. This term was coined in the 1980s when AI research was struggling to secure funding, but was later revived by the commercial success of expert systems.
# 38 Herbert Simon predicted that machines would be capable of doing any work a man can do within twenty years.
# 39 The Lisp Machine market collapsed in 1987.
# 40 The company's name is TJX Companies (TJX).
# 41 The two parties are the Democratic Party and the Republican Party.
# 42 The employment is expected to commence on April 16, 2012.
# 43 The owner of the intellectual property depends on the specific situation. In some cases, it may be the individual who created the work, while in others it may be a company or organization. It is important to consult with a legal professional to determine the ownership of intellectual property in a specific context. Is there a specific situation you are referring to?
# 44 The notice period to terminate for convenience is typically outlined in the contract or agreement between the parties involved. It can vary depending on the specific terms and conditions of the contract, so it is important to review the document carefully.
# 45 Termination after a material breach can occur if the other party is in default of any obligation and does not cure the breach within 15 days of notice.
# 46 Yes, the agreement can be terminated. However, the specific terms and conditions for termination may vary depending on the agreement itself. It is important to carefully review the agreement and consult with legal counsel if necessary to fully understand the termination process.
# 47 The executive's role is Senior Vice President, Event Planning ("SVP") of the Employer's Workforce Optimization Division.
# 48 I'm sorry, I cannot provide specific information about an executive's salary. This information is confidential and not publicly available. Is there something else I can assist you with?
# 49 The section that defines the base salary is typically found in the employment contract or offer letter. It outlines the specific amount of money that an employee will receive as their base salary, before any additional bonuses or benefits are added. Is there anything else I can assist you with?
# 50 The Board will review the salary on an annual basis.
# 51 The governing law is the laws of the State of Massachusetts, except for Section 18(a) which is governed by the laws of the State of Delaware.
# 52 Section 18(a) is governed by the United States Code, specifically Title 18 which covers crimes and criminal procedure. Is there a specific aspect of section 18(a) that you would like more information on?
# 53 The governing law is defined in the section titled "Governing Law" in the agreement. This section outlines which laws and jurisdiction will apply to the agreement. Is there anything else I can assist you with?
# 54 The Dow Jones Industrial Average gained 195.12 points, or 0.76%, on Friday.
# 55 I'm not sure what specific context you're referring to, but according to the Bureau of Labor Statistics, there were 1.4 million new jobs added in August 2021. Is there a particular industry or sector you're interested in?
# 56 According to recent data, economists have predicted that there will be approximately 7.2 million job openings in the United States by the end of 2021. This is a significant increase from the previous year and is a positive sign for the economy.
# 57 The Nasdaq Composite rose 1.35% at closing.
# 58 Margaret Jones' place of employment is located in the state and county specified in the contract. She has also consented to the jurisdiction and service of any legal proceedings in that location.
# 59 The current rate on 10-year treasuries is 4.9%. This is the highest level in 16 years and has caused a decline in the S&P 500 and Dow, as well as raising questions about the Federal Reserve's monetary policy.
# 60 The CEO's salary is currently $350,000. However, the board has recently approved a $25,000 increase, bringing their total salary to $375,000.
#
#
# 61 I'm sorry, I cannot provide stock prices as I am not connected to the stock market.
# 62 I'm sorry, I don't have enough information to answer that question. Could you provide more context or specify which Bob you are referring to?
# 63  To send notices to Red River Industries, send to: One Red River Road, Stamford, Connecticut 08234.
#
# 64 Brian served as head of Northeast Sales at XYZ Corporation.
# 65 Mr. Williams is the CEO of Washtec Industries. He oversees the overall operations and strategic direction of the company.
# 66 I'm sorry, I do not have access to that information.
# 67 The revenue in the second quarter was $13.51 billion, up 101% from a year ago and up 88% from the previous quarter.
# 68 I'm sorry, I don't have enough information to answer that question. Could you provide more context or specify which company you are referring to?
# 69 The current CEO of Nvidia is Jensen Huang.
# 70 According to our latest report, data center revenue saw a 10% increase compared to the first quarter. This is a positive sign for our company's growth in this sector.
# 71 GAAP earnings per share for the quarter is a financial metric that measures the amount of net income earned per share of common stock outstanding during a specific period of time, in accordance with Generally Accepted Accounting Principles (GAAP). This information can typically be found in a company's quarterly financial statements.
# 72 The next dividend will be paid on the scheduled date, which can be found on the company's investor relations website or in their financial reports.
# 73 The percentage increase in non-GAAP earnings from the previous quarter is currently unavailable. However, we can provide you with the exact figures for the previous quarter and the current quarter, so you can calculate the percentage increase yourself. Would you like us to provide you with those figures?
# 74 Yes, the expected gross margin is greater than 70%.
# 75 The expected revenue for the third quarter is currently being projected and will be announced at the end of the second quarter. We are constantly monitoring our financial performance and will provide updates as they become available. Thank you for your interest in our company's growth.
# 76 The new product that is shipping in the quarter is our latest smartphone model, which has been highly anticipated by our customers. It boasts advanced features and improved performance, making it our most innovative product yet. We are confident that it will be a huge success in the market.
# 77 The forecast tax rate is not provided in the given context.
# 78 I'm sorry, I cannot provide specific financial information as I am a language model. It would be best to consult the company's financial reports for this information.
# 79 The expected GAAP operating expense for the third quarter of fiscal 2024 is approximately $2.95 billion.
# 80 Gaming revenue in the second quarter was $2.49 billion, which is an 11% increase from the previous quarter and a 22% increase from a year ago.
# 81 I'm sorry, I am not able to answer that question as it is not related to the context provided. Is there something else I can assist you with?
# 82 I'm sorry, I cannot answer that question as it is not related to the given context. This context is about a contract between TestCo and Customer, and an invoice from Services Vendor Inc. Is there something else I can assist you with?
# 83 The Alliance for OpenUSD currently has over 20 participating companies, including Pixar, DreamWorks Animation, and Sony Pictures Imageworks.
# 84 35 DLSS games were added in the second quarter, including popular titles such as Diablo IV, Ratchet & Clank: Rift Apart, Baldur’s Gate 3, and F1 23.
#
#
# 85 The lowest price for the GeForce RTX 4060 family is currently unknown as it has not been officially released yet. However, based on previous releases, it is expected to be around $300-$400.
# 86 NVIDIA's partner for the driver assistance system is MediaTek.
# 87 The former name of LSEG was London Stock Exchange Group.
# 88 The current chairman of the Federal Reserve is Jerome Powell.
# 89 Japan had a trade surplus in September.
# 90 I'm sorry, I cannot provide specific data without a source.  However, according to the World Bank, Japan's imports have been steadily declining since 2019.
# 91 The trade surplus is the amount by which a country's exports exceed its imports. It is an indicator of a country's economic strength and competitiveness in the global market.
# 92 Economists were expecting the trade surplus amount to increase due to the recent trade policies implemented by the government.
# 93 I'm sorry, I cannot answer that question as I do not have access to current export data.
# 94 I'm sorry, I cannot provide historical data. My focus is on current market news and events.
# 95 I'm sorry, I cannot predict the cost of living adjustment for 2024 as it is dependent on various economic factors and can only be determined closer to the date.
# 96 Bank of America upgraded Target (TGT) to buy from neutral.
#
#
# 97 Bank of America's rating on Snowflake is currently not publicly available. However, Bank of America has been a long-time partner of Snowflake and has invested in the company's growth.
# 98 Barclay's new price target on UTZ is $25 per share.
# 99 The third quarter profit for Microsoft was $18.3 billion, which is a 9% increase from the corresponding period of last fiscal year. This growth was driven by the strength of Microsoft's cloud services.
# 100 The purchase order number is 234.
# 101 The EVP of Human Resources is not mentioned in the context provided. The context only mentions the SVP of Event Planning and the Board of Directors.
# 102 The annual bonus amount varies depending on performance and company policies. It is typically a percentage of your salary and can range from a few thousand dollars to tens of thousands of dollars.
# 103 The address of Simmons Technologies is 123 Main Street, Anytown, USA.
# 104 I'm sorry, I cannot provide specific financial information without proper authorization. Is there something else I can assist you with?
# 105 I'm sorry, I cannot provide financial advice or predictions. My purpose is to provide information and context related to the stock market.  Is there something else I can assist you with?
# 106 The A100 chip was released in May 2020.
# 107 I'm sorry, I cannot provide specific financial information. However, I can tell you that the gaming industry has been steadily growing in recent years.
# 108 Third quarter revenue was $52.9 billion, which is a 7% increase from the corresponding period of last fiscal year.
# 109 I'm sorry, I cannot provide specific financial information as I am an AI and do not have access to that data. However, according to recent reports, the global gaming industry is expected to generate over $159 billion in revenue in 2020.
# 110 The current CEO of Netflix is Reed Hastings.
# 111 China's trade balance in September was a deficit of 42.5 billion yen, which was lower than expected. This was due to a decrease in imports and an increase in exports to Western markets.
# 112 I'm sorry, I cannot answer that question as the context provided is for September.
# 113 The cost of living adjustment for 2023 was not announced by the Social Security Administration. However, they did announce a 3.2% cost-of-living adjustment for 2024.
# 114 TJX Companies, Inc. is expected to report their earnings for the current quarter on May 19, 2021.
# 115 I'm sorry, I don't have any information on that.
# 116 The current secretary of agriculture is Tom Vilsack. He was confirmed by the Senate on February 23, 2021.
#
#
# 117 The executive's salary is $200,000 per year, payable semimonthly. However, it may be increased annually by the Board or the compensation committee of the Board, in accordance with the company's normal compensation and performance review policies for senior level executives.
#
#
# 118 I'm sorry, I cannot provide specific financial information for companies. My purpose is to provide general information and insights on the stock market.
# 119 I'm sorry, I cannot answer that question as I do not have enough information about Maribeth. Could you provide more context or specify which Maribeth you are referring to?
# 120 Yes, the S&P 500 index has increased by more than 22% since its bear market bottom of 3,577 one year ago.
# 121 I'm not sure, but I can check for you. Would you like me to search for any recent news or announcements from Chipotle about their prices?
# 122 I'm sorry, I cannot answer that question as it is not mentioned in the provided context.  Could you please provide more information?
# 123 Yes, according to our latest financial report, third quarter sales were more than 5 billion euros. Our company has seen a significant increase in sales this quarter, thanks to our new product launch and successful marketing strategies. We are confident that this positive trend will continue in the upcoming quarters.
# 124 I'm sorry, I cannot provide information on the trade surplus as it is not mentioned in the context provided. However, I can tell you that the consumer price index for September was higher than expected, which could potentially impact the trade surplus.
# 125 Yes, according to the context provided, Dow Jones Industrial futures increased by 23 points, or 0.07%.
# 126 Yes, the yield on the 10-year is currently above 4.8%. This is the highest level it has reached in 16 years and has caused a decline in the stock market. Traders are now looking to a key speech from Federal Reserve Chair Jerome Powell to see how the central bank will respond to the rising interest rates. Other economic data, such as weekly jobless claims and existing home sales, will also be released for September.
# 127 Yes, the Nasdaq Composite rose 1.35% on Friday.
# 128 Yes, according to our latest financial report, automotive revenue did increase in the current quarter compared to last quarter. This can be attributed to the successful launch of our new line of electric vehicles and increased demand for our existing models. We are pleased with this growth and will continue to strive for further success in the automotive industry.
# 129 Yes, according to our latest financial report, automotive revenue increased by 10% compared to the previous year. This can be attributed to the successful launch of our new line of electric vehicles and increased demand in the market.
# 130 I'm sorry, I cannot provide an answer without more context. Can you please provide more information about the specific company or time period you are referring to?
# 131 Yes, according to recent reports, gaming revenue has decreased due to the COVID-19 pandemic. Many gaming events and conventions have been cancelled, leading to a decline in revenue for the industry. However, online gaming and streaming platforms have seen an increase in usage and revenue during this time.
# 132 I'm sorry, I cannot answer that question without more context. Can you provide more information about the company or industry you are referring to?
# 133 Yes, according to the company's financial report, more than $3 billion was returned to shareholders in the quarter.
# 134 Yes, according to Microsoft's financial report for the fiscal year 2020, Windows OEM revenue increased by 5% compared to the previous year. This was driven by strong demand for Windows 10 and growth in the commercial PC market.
# 135 Nokia's products have been facing challenges in the market, which is why they have announced a cost cutting plan and layoffs. However, they are working to improve their efficiency and address the challenging market environment.
# 136 Yes, Nokia has been facing challenges with sales in recent years due to increased competition from other smartphone brands. However, the company has been implementing new strategies and launching innovative products to improve its sales performance.
# 137 According to the data, Japan's exports to Asia have actually been falling for the past nine months. However, exports to Western markets have been increasing, which has helped to offset the decline in exports to Asia.
# 138 Yes, according to the data from Japan's customs agency, exports in September increased 4.3% year on year. This was supported by shipments to Western markets, while exports to Asia fell for the ninth straight month due to ongoing China weakness.
# 139 Yes, the executive's base salary is $250,000.
# 140 The amount would be $100 million.
# 141 The new price would be the current price plus $2.
# 142 The new price would be the current price minus $3.
# 143 The loan will expire on January 15, 2019.
# 144 Bryan's current age would depend on his birth year. If he was born in 2000, he would be 22 years old in 2022. If he was born in 1990, he would be 32 years old in 2022. Without knowing his birth year, it is impossible to accurately determine his current age.
# 145 I'm sorry, I cannot answer that question as I do not have access to that information.
# 146 The last day to pay the invoice will be on the due date stated on the invoice. If you need an extension or have any questions, please let us know as soon as possible.
# 147 I'm sorry, I don't have access to real-time stock market data. Is there something else I can assist you with?
# 148 The new rental price would be $1800 per month.
# 149 The target bonus is 50% of the base salary amount each year, which is $100,000.
#
#
# 150 Bob is 61 years old, Margaret is 46 years old, John is 32 years old.
# 151 It is not specified who Elizabeth and John are, so I cannot determine who is older. Can you provide more context?
# 152 I'm sorry, I don't have information on specific item prices. My focus is on stock prices and market trends.
# 153 The item with the highest price is the one that costs the most money.
# 154 It depends on the brand and quality of the chocolate and coffee. Generally, high-quality chocolate tends to be more expensive than high-quality coffee. However, there are also expensive specialty coffees that can be more expensive than some types of chocolate.  So, it's difficult to say definitively which one has a higher price.
# 155 The Dow Jones Industrial Average increased by the most points yesterday, gaining 195.12 points.
# 156 The S&P 500 had the highest percentage increase yesterday, gaining 1.59%.
# 157 The stock with the highest price is the one that closed at $36 per share on Friday.
# 158 The new price of Smithson stock would be the current price plus $2.
# 159 I'm sorry, I cannot answer that question without more context. Could you provide me with the specific PO numbers you are referring to?
# 160 The amount of Cloud revenue in the quarter was $52.9 billion.
# 161 The name of the company is (B) TestCo Software.
#
#
# 162 The price for the services of the Quality Assurance Manager is $10,000.
# 163 The percentage increase in diluted earnings per share in constant currency was (C) 14%.
# 164 The rate of decline in profit cannot be determined from the given information.
# 165 The list of net sales in 2019, 2020, 2021, and 2022 is 24,578, 31,536, 53,823, and 81,462 respectively.
# 166 Non-operating income interest in 2022 refers to the interest earned on investments or loans that are not directly related to the company's main operations. This can include interest earned on savings accounts, bonds, or other investments. It is important for companies to track their non-operating income interest as it can impact their overall financial performance.
# 167 Operating Income in 2021 is the amount of profit a company has earned after deducting all operating expenses. It is an important measure of a company's financial health and can be found in the company's income statement.
# 168 The cost of goods sold (excluding depreciation) in 2019 was $18,402.
# 169 I'm sorry, I am an AI and do not have access to current financial information. My focus is on the history and development of AI.
# 170 John, Margaret, and Bob are all mentioned in the context.
# 171 The partners mentioned in the text are Pixar, Adobe, Apple, and Autodesk.
# 172 There are several companies mentioned in the text, including Apple, Google, Microsoft, and Amazon. Is there a specific company you are interested in learning more about?
# 173 The three governments mentioned in the text are the United States, China, and Russia.
# 174 The intraday reversal may have occurred due to a combination of factors, including the softer wage number in the jobs report and the pullback in yields from the day's highs. Additionally, the market may have been oversold, leading to a rally as investors reevaluated their earlier bearish stance.
# 175 Nokia is cutting jobs in order to restructure and focus on their core business areas. This decision was made in response to changes in the market and to ensure the company's long-term success.
# 176 The decline in Tesla stock could be attributed to the overall market downturn, as well as concerns about rising interest rates and potential changes in monetary policy. Additionally, Tesla's third quarter earnings report showed lower than expected earnings and revenue, which may have also contributed to the decline.
# 177 The electoral victories in Georgia by Jon Ossoff and Raphael Warnock, as well as President-elect Biden's support and campaigning for both candidates, played a significant role in the Democrats winning control of the Senate. Additionally, the violent storming of the Capitol by Trump supporters on January 6 may have also influenced the outcome of the election.
# 178 There are several companies located in Nevada, including Tesla, MGM Resorts International, and Caesars Entertainment. Is there a specific company you are interested in?
# 179 Blue Moon Tech  is located on California Street.
# 180 The key financial metrics for the outlook of the third quarter will depend on the specific company or industry you are referring to. However, some common metrics that are often used to evaluate financial performance include revenue growth, profit margins, return on investment, and cash flow. These metrics can provide insight into the overall health and potential of a company during a specific time period. Is there a particular company or industry you are interested in?
# 181 There are several key points to keep in mind when evaluating data center performance. First, it's important to consider the reliability and uptime of the data center. This includes factors such as power supply, cooling systems, and backup generators. Second, network connectivity and bandwidth are crucial for efficient data transfer. Third, security measures, such as firewalls and encryption, are essential for protecting sensitive data. Fourth, scalability and flexibility are important for accommodating future growth and changes in technology. Finally, cost-effectiveness is a key factor in determining the overall performance of a data center.
# 182 1. Revenue increased by 7% (10% in constant currency)
# 2. Operating income increased by 10% (15% in constant currency)
# 3. Net income increased by 9% (14% in constant currency)
#
# 183 A list of the top summary points is a collection of the most important and relevant information or key takeaways from a larger piece of content, such as a report, article, or presentation. It is often used to provide a quick overview or summary of the main points without having to read or review the entire content. Is there a specific topic or subject you would like a list of top summary points for?
# 184 I'm sorry, I'm not sure what you mean by "list of the top 5 summary points." Can you provide more context or clarify your question?
# 185 The top financial highlights for the quarter can vary depending on the company, but some common ones include revenue growth, profit margins, earnings per share, and cash flow. Is there a specific company or industry you are interested in?
# 186 A list of the top 3 points can vary depending on the context. Can you provide more information about what you are looking for?
# 187 A list of the top summary points is a collection of the most important and relevant information or key takeaways from a larger body of text or data. It is often used to provide a quick overview or summary of the main points without having to read through the entire text. Is there a specific topic or subject you would like a list of top summary points for?
# 188 On Wednesday, the stock price was $27. On Thursday, the stock was trading at $33. On Friday, the stock price increased by another $3 to $36.
# 189 A headline summary is a short description of a news story.
# 190 A one-line brief description is a concise summary of a project or agreement, typically no longer than 25 words.
# 191 Some of the top Microsoft product offerings include Windows operating system, Microsoft Office suite, Microsoft Azure cloud computing platform, Microsoft Surface devices, and Xbox gaming consoles.  Is there a specific product you are interested in learning more about?
# 192 A list of key points is a collection of important or essential information that summarizes the main ideas or concepts of a topic. It can be used as a study guide or reference for understanding the main points of a subject. Is there a specific topic you would like a list of key points for?
# 193 A summary is a brief overview of a longer text or document, typically 30 words or less, that highlights the main points and key information.
# 194 John, Margaret, Bob, Susan, Michael, and Wilma are all mentioned in the context.
# 195 The one-line summary is that this Agreement will remain in effect until terminated, with either party having the option to terminate with 30 days written notice or in the case of a material breach or default, with 15 days notice. The TestCo agrees to pay all fees and expenses incurred prior to termination, and termination of this Agreement will also terminate any outstanding Statement of Work or Services Description. Additionally, an invoice was issued on January 12 with a 3-day payment deadline.
#
# 196 As Senior Vice President, Event Planning, the executive will be responsible for running the day-to-day operations of the Employer's Workforce Optimization Division. This includes reporting to the Board of Directors, devoting their time and attention to the operations of the company, and performing their duties and responsibilities faithfully, diligently, and competently. They may also be directed by the Board to take on additional responsibilities consistent with their position.  Is there anything specific you would like to know about their responsibilities?
#
#
# 197 A headline description is a brief summary of the main points of an article or news story. It is usually found at the top of the article and gives readers an idea of what the article is about.
# 198 The CEO's statement is a brief overview of the company's current status and future plans.
# 199 The key terms of the invoice are the due date, which is May 3, 2022, and the payment terms, which state that the invoice must be paid in full within 3 days.  Is there anything else you would like to know?

# %%
df.head()
# Out:
#                                            query  \
# 0       What is the total amount of the invoice?
# 1                    What is the invoice number?
# 2   What is a list of the items being purchased?
# 3  What is the name of the contact for question?
# 4                         What is the PO number?
#
#                                               answer  \
# 0                                         $22,500.00
# 1                                              #0001
# 2  •Front End Engineering Service;\n•Back End Eng...
# 3                                         Bia Hermes
# 4                                              #1000
#
#                                              context  sample_number  tokens  \
# 0  Services Vendor Inc. \n100 Elm Street Pleasant...              0     138
# 1  Services Vendor Inc. \n100 Elm Street Pleasant...              1     138
# 2  Services Vendor Inc. \n100 Elm Street Pleasant...              2     138
# 3  Services Vendor Inc. \n100 Elm Street Pleasant...              3     138
# 4  Services Vendor Inc. \n100 Elm Street Pleasant...              4     138
#
#   category
# 0     core
# 1     core
# 2     core
# 3     core
# 4     core

# %%
data = {'synthesis': results, 'actual': df['answer'], 'context': df['context'], 'query': df['query']}

# %%
pd.DataFrame(data).to_csv('zero_shot_rag_flare_syntheses.csv')
