# %%
import pandas as pd 
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from typing import List
import os 
import numpy as np

# %%
def compute_rouge_l(candidate, reference):
    m, n = len(candidate), len(reference)
    #print(m,n)
    dp_table = [[0] * (n + 1) for _ in range(m + 1)]
    
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if candidate[i - 1] == reference[j - 1]:
                dp_table[i][j] = dp_table[i - 1][j - 1] + 1
            else:
                dp_table[i][j] = max(dp_table[i - 1][j], dp_table[i][j - 1])
    
    return dp_table[m][n] / n

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\liang\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def preprocess_text(text):
    # Tokenize the text
    #tokens = word_tokenize(text.lower())
    tokens = word_tokenize()

    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]
    
    return filtered_tokens

# %%
def preprocess_text(text):
    # Tokenize the text
    tokens = word_tokenize(text.lower())
    
    return tokens

# %%
rag_flare_df = pd.read_csv('rag_flare_syntheses.csv')

# %%
# Fill NaN values in the 'actual' column with the string value 'None'
rag_flare_df['synthesis'].fillna('None', inplace=True)

# %%
rag_flare_df.isnull().sum()
# Out:
# Unnamed: 0.1     0
# Unnamed: 0       0
# synthesis        0
# actual           0
# evidence_text    0
# question         0
# dtype: int64

# %%
rag_flare_df.to_csv('rag_flare_syntheses.csv')

# %%
def compute_similarity_score(answer,syntheses):
    tokens_answer = preprocess_text(answer)
    tokens_syntheses = preprocess_text(syntheses)
    str_answer = ' '.join(tokens_answer)
    str_syntheses = ' '.join(tokens_syntheses)
    freqdist_answer = nltk.FreqDist(str_answer.split())
    freqdist_syntheses = nltk.FreqDist(str_syntheses.split())
    # Extract frequencies for unique tokens in both texts
    unique_tokens = set(freqdist_answer.keys()).union(freqdist_syntheses.keys())

    freq_answer = [freqdist_answer[token] for token in unique_tokens]
    freq_syntheses = [freqdist_syntheses[token] for token in unique_tokens]

    vector_answer = np.array(freq_answer).reshape(1, -1)
    vector_syntheses = np.array(freq_syntheses).reshape(1, -1)

    similarity_score = cosine_similarity(vector_answer, vector_syntheses)[0][0]

    return similarity_score

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()

# %%
#total_average_rouge_l_scores = []
#total_average_cosine_similarity_scores = []

rouge_l_scores = [] 
cosine_similarity_scores = [] 

for idx, row in rag_flare_df.iterrows():
    answer = row['actual']
    syntheses = row['synthesis'] 
    print(answer,syntheses)

    compute_sim_score = compute_similarity_score(answer, syntheses)
    cosine_similarity_scores.append(compute_sim_score)

    rouge_l_score = compute_rouge_l(answer, syntheses)
    rouge_l_scores.append(rouge_l_score)

total_average_cosine_similarity_score = sum(cosine_similarity_scores) / len(cosine_similarity_scores)

total_average_rouge_l_score = sum(rouge_l_scores) / len(rouge_l_scores)
# Out:
# $1577.00 The FY2018 capital expenditure amount for 3M was $1,749 million. This can be found in the "Cash Flows from Investing Activities" section of the Consolidated Statement of Cash Flows for the year ended December 31, 2018.
# $8.70 The year end FY2018 net PPNE for 3M was $8.738 billion.  This information can be found on the balance sheet under the "Property, Plant and Equipment" section.
# No, the company is managing its CAPEX and Fixed Assets pretty efficiently, which is evident from below key metrics:
# CAPEX/Revenue Ratio: 5.1%
# Fixed assets/Total Assets: 20%
# Return on Assets= 12.4% Yes, based on the data provided, 3M appears to be a capital-intensive business with a significant amount of property, plant, and equipment, as well as other assets. This is likely due to the nature of their business, which involves manufacturing and producing physical products.
# Operating Margin for 3M in FY2022 has decreased by 1.7% primarily due to:
# -Decrease in gross Margin
# -mostly one-off charges including Combat Arms Earplugs litigation, impairment related to exiting PFAS manufacturing, costs related to exiting Russia and divestiture-related restructuring
# charges 3M's operating margin change as of FY2022 may have been driven by a variety of factors, such as changes in revenue, expenses, or overall market conditions. However, it's important to note that operating margin may not always be the most useful metric for evaluating a company's financial performance. This is because it only takes into account a company's operating income and does not consider other important factors such as taxes, interest, and non-operating expenses. Therefore, it's important to also consider other metrics and financial indicators when evaluating a company's overall financial health.
# The consumer segment shrunk by 0.9% organically. It appears that the Industrial segment has been the main factor in dragging down 3M's overall growth in 2022, as it has experienced a decline in sales and profitability. This could be due to various factors such as a slowdown in the manufacturing industry or increased competition. However, it is important to note that excluding the impact of M&A, the other segments have shown positive growth.
# No. The quick ratio for 3M was 0.96 by Jun'23 close, which needs a bit of an improvement to touch the 1x mark 3M's quick ratio for Q2 of FY2023 is 1.08, which indicates a reasonably healthy liquidity profile. The quick ratio measures a company's ability to meet its short-term financial obligations with its most liquid assets. A ratio of 1 or higher is generally considered healthy, so 3M's quick ratio suggests that it has enough liquid assets to cover its short-term liabilities. However, it is important to note that the quick ratio is just one measure of liquidity and should be considered alongside other financial metrics.
# Following debt securities registered under 3M's name are listed to trade on the New York Stock Exchange:
# -1.500% Notes due 2026 (Trading Symbol: MMM26)
# -1.750% Notes due 2030 (Trading Symbol: MMM30)
# -1.500% Notes due 2031 (Trading Symbol: MMM31) As of Q2 of 2023, 3M has registered their debt securities to trade on the following national securities exchanges: New York Stock Exchange, NASDAQ, and Chicago Stock Exchange. These exchanges are regulated by the Securities and Exchange Commission (SEC) and provide a platform for investors to buy and sell 3M's debt securities.
# Yes, not only they distribute the dividends on a routine basis, 3M has also been increasing the per share dividend for consecutive 65 years Yes, 3M has a history of maintaining a stable trend of dividend distribution. In fact, they have increased their dividend for 62 consecutive years, making them a reliable choice for investors seeking consistent dividend income.
# 24.26 The FY2019 fixed asset turnover ratio for Activision Blizzard is 0.03. This is calculated by dividing the FY2019 revenue of $6,489 million by the average PP&E between FY2018 and FY2019, which is ($253 million + $282 million) / 2 = $267.5 million. Therefore, the fixed asset turnover ratio is $6,489 million / $267.5 million = 0.03.  This information can be found in the statement of income and the statement of financial position.
# 1.9% The FY2017 - FY2019 3 year average of capex as a % of revenue for Activision Blizzard is 4.3%. This was calculated by dividing the average of the total capital expenditures for the years 2017, 2018, and 2019 by the average of the total net revenues for the same years, and then multiplying by 100 to get the percentage.
# 0.66 The FY2015 operating cash flow ratio for Adobe is not available as it is a private company and does not disclose its financial statements publicly. However, you can calculate the operating cash flow ratio using the statement of financial position and the cash flow statement provided. Simply divide the cash from operations by the total current liabilities and round the answer to two decimal places. This will give you the operating cash flow ratio for Adobe in FY2015.
# 65.4% The year-over-year change in unadjusted operating income from FY2015 to FY2016 is 19.2%. This can be calculated by taking the difference between the operating income in FY2016 (6,098) and FY2015 (5,802), which is 296, and dividing it by the operating income in FY2015 (5,802). Then, multiply by 100 to get the percentage and round to one decimal place.  This information can be found on Adobe's income statement.
# 0.83 The FY2017 operating cash flow ratio for Adobe is 2.08. This is calculated by dividing the cash from operations of $2,471,997 by the total current liabilities of $1,189,000.  This information can be found on the balance sheet and cash flow statement.
# No the operating margins of Adobe have recently declined from 36.8% in FY 2021 to 34.6% in FY2022. A drop by 2.2% in a year. Adobe's operating margin has been steadily improving over the past few years, with a significant increase in FY2022 compared to FY2021 and FY2020. However, operating margin may not be the most useful metric for a company like Adobe, as it primarily focuses on software and services rather than physical products. Other metrics, such as subscription growth and customer retention, may be more relevant in evaluating Adobe's performance.
# Yes, the FCF conversion (using net income as the denominator) for Adobe has improved by ~13% from 143% in 2021 to 156% in 2022 Yes, according to Adobe's financial reports for FY2022, their free cashflow conversion has been steadily improving. This is due to their strong revenue growth and efficient cost management strategies.
# 0 0
# AES has converted inventory 9.5 times in FY 2022. The inventory turnover ratio for AES Corporation in FY2022 is not applicable as the company does not have a conventional inventory management system. This is because AES Corporation is primarily a service-based company and does not rely heavily on inventory for its operations. Therefore, the concept of inventory turnover ratio is not meaningful for the company.
# -0.02 None
# 93.86 Amazon's FY2017 days payable outstanding (DPO) was 44.86 days. This is calculated by taking 365 * (average accounts payable between FY2016 and FY2017) / (FY2017 COGS + change in inventory between FY2016 and FY2017). Using the information provided in the balance sheet and the P&L statement, the average accounts payable between FY2016 and FY2017 was $10,751.5 million, the FY2017 COGS was $111,934 million, and the change in inventory between FY2016 and FY2017 was $4,586 million. Plugging these values into the formula, we get 365 * ($10,751.5 million) / ($111,934 million + $4,586 million) = 44.86 days.
# 30.8% According to Amazon's statement of income, their revenue increased by 27.8% from FY2016 to FY2017. This is calculated by taking the difference between the revenue for FY2017 and FY2016, which is $136 billion and $107 billion respectively, and dividing it by the revenue for FY2016. This results in a year-over-year change of 27.8%.
#
#
# $11588.00 According to Amazon's FY2019 income statement, the net income attributable to shareholders was $11.59 billion USD. This information can be found in the "Net Income" section of the income statement.
# $1616.00 Based on the information provided in the Amcor plc and Subsidiaries Consolidated Balance Sheet, the net accounts receivable for the fiscal year 2020 was $1,615.9 million. This can be found under the current assets section, specifically under trade receivables, net. As a financial analyst, it is important to note that this figure may not reflect the current net accounts receivable as it is from the previous fiscal year. It would be necessary to review the current financial statements to obtain the most accurate and up-to-date information.
# Amcor Finance (USA), Inc. and Amcor Flexibles North America, Inc., entered into supplemental indentures relating to Guaranteed Senior Notes due 2026 and 2028. This involved the substitution of the Substitute Issuer (Amcor Flexibles North America) for the Former Issuer (Amcor Finance) and the assumption of covenants under the indentures. (In essence a novation agreement) The key agenda of AMCOR's 8k filing dated 1st July 2022 was to provide an update on the company's financial performance and any significant events that may have occurred since the last filing. This filing is required by the Securities and Exchange Commission (SEC) and is used to keep shareholders and the public informed about the company's operations.
# The quick ratio has slightly improved from 0.67 times to 0.69 times between FY 2023 and FY 2022.(3.4% jump) None
# Amcor completed these acquisitions during FY2023:
# -100% equity interest of a flexibles manufacturing company in the Czech Republic
# - 100% equity interest in a medical device packaging manufacturing site in
# Shanghai, China.
# -acquisition of a New Zealand-based leading manufacturer of state-of-the-art, automated protein
# packaging machines. AMCOR has made several major acquisitions in the past few years, including the purchase of Bemis Company in FY2023, the acquisition of Birla Carbon in FY2022, and the merger with Alcan Packaging in FY2021. These strategic moves have helped AMCOR expand its global presence and strengthen its position in the packaging industry.
# Amcor is a global leader in packaging production for various use cases. AMCOR primarily operates in the packaging industry, providing packaging solutions for various products such as food, beverages, pharmaceuticals, and personal care items.
# No. For AMCOR there has been a slight decline in gross margins by 0.8%. AMCOR's gross margin profile has been steadily improving over the past few years, with a projected increase in FY2023. However, it is important to note that gross margin may not be the most useful metric for evaluating a company like AMCOR, as it primarily focuses on the cost of goods sold and does not take into account other important factors such as operating expenses and revenue growth. Therefore, while AMCOR's gross margin may be improving, it is important to also consider other metrics when evaluating the company's overall financial health.
# 87% of the total restructuring liability is related Employee liabilities. AMCOR's restructuring liability refers to the amount of money that the company has set aside for potential costs associated with restructuring its operations. This could include expenses related to downsizing, reorganizing, or closing certain parts of the business. The purpose of this liability is to ensure that the company has enough funds to cover these costs and minimize any negative impact on its financial performance. As of Q2 of FY2023 close, the exact amount of this liability will be determined and disclosed in the company's financial statements.
# AMCOR's Adj. EBITDA was $2,018mn in FY 2023 I'm sorry, I cannot provide financial information for future years. Is there something else I can assist you with?
# The Real Growth was flat in FY 2023 vs FY 2022. Unfortunately, I do not have access to that specific information. However, you can find the exact change in sales for AMCOR in FY 2023 vs FY 2022 by excluding the impact of FX movement, passthrough costs, and one-off items by looking at their financial reports or contacting their investor relations team.
# 4.2% Unfortunately, without internet connection, I am unable to access the financial metric providers to provide an accurate answer to your question. However, I can suggest looking at the P&L statement and the statement of cash flows to determine the FY2015 depreciation and amortization (D&A from cash flow statement) % margin for AMD. These documents should provide the necessary information to calculate the D&A % margin. I apologize for any inconvenience this may cause.
# Yes. The quick ratio is 1.57, calculated as (cash and cash equivalents+Short term investments+Accounts receivable, net+receivables from related parties)/ (current liabilities). AMD's quick ratio for FY22 is currently at a healthy level, indicating that the company has enough liquid assets to cover its short-term liabilities. However, it is important to note that the quick ratio is just one measure of liquidity and should not be the sole factor in determining a company's overall liquidity profile. Other factors such as cash flow, debt levels, and market conditions should also be taken into consideration.
# AMD sells server microprocessors (CPUs) and graphics processing units (GPUs), data processing units (DPUs), Field Programmable Gate Arrays (FPGAs), and Adaptive System-on-Chip (SoC) products for data centers; CPUs, accelerated processing units (APUs) that integrate CPUs and GPUs, and chipsets for desktop and notebook personal computers; discrete GPUs, and semi-custom SoC products and development services; and embedded CPUs, GPUs, APUs, FPGAs, and Adaptive SoC products. As of FY22, AMD's major products and services include computer processors, graphics cards, and server processors. They also offer software and hardware solutions for data centers and cloud computing. Additionally, AMD provides semi-custom solutions for gaming consoles and other embedded applications.
# In 2022, AMD reported Higher sales of their EPYC server processors, higher semi-custom product sales, and the inclusion of Xilinx embedded product sales There were a few factors that contributed to the revenue change for AMD in FY22. One of the main drivers was the increased demand for their products in the gaming and data center markets. Additionally, AMD's new product releases, such as their Ryzen and EPYC processors, were well-received and helped drive revenue growth. Another factor was the company's focus on cost-cutting measures and improving operational efficiency. Overall, these factors combined to result in a significant revenue increase for AMD in FY22.
# The decrease in AMD's operating income was primarily driven by amortization of intangible assets associated with the Xilinx acquisition Operating margin change can be driven by a variety of factors, such as changes in revenue, expenses, or overall market conditions. It is important to note that operating margin may not always be the most useful metric for evaluating a company's performance, as it does not take into account other important factors such as cash flow and debt. However, for a company like AMD, operating margin can still provide valuable insights into their financial health and efficiency.
# In 2022, AMD brought in the most cashflow from Operations According to AMD's financial statements for FY22, the investing activities brought in the most cash flow. This includes the sale of assets, investments in securities, and other long-term investments. However, it is important to note that the financing activities also had a positive impact on cash flow, as the company was able to secure loans and issue stocks to raise capital. Overall, both investing and financing activities contributed to AMD's positive cash flow in FY22.
# Data Center In FY21, AMD's Computing and Graphics segment saw the highest proportional increase in sales compared to FY22, excluding Embedded. This was due to strong demand for AMD's Ryzen processors and Radeon graphics cards.
# Yes, one customer accounted for 16% of consolidated net revenue Yes, AMD did report customer concentration in their FY22 financial report. They stated that their top five customers accounted for approximately 65% of their total revenue.
# There are none As of 2022, American Express has registered several debt securities to trade on national securities exchanges. These include corporate bonds, commercial paper, and asset-backed securities. Is there a specific type of debt security you are interested in?
# United States, EMEA, APAC, and LACC As of 2022, American Express primarily operates in the United States and other countries around the world.
# Performance is not measured through operating margin As of 2022, AMEX has shown a consistent and improving operating margin profile. This metric is useful for a company like AMEX as it measures the efficiency of the company's operations and how well it is able to control costs. However, it is important to also consider other metrics such as return on equity and earnings per share to get a more comprehensive understanding of the company's financial health.
# Performance is not measured through gross margin None
# The effective tax rate for American Express has changed/dropped from 24.6% in FY 2021 to 21.6% in FY 2022. The effective tax rate of American Express has not changed between FY2021 and FY2022.
# Customer deposits The largest liability in American Express's Balance Sheet in 2022 was customer deposits, with a total of $110,239.
# Yes I'm sorry, I cannot answer that question as it is in the future.
# $0.40 American Water Works paid out $182 million in cash dividends for FY2020. This information can be found in the "Changes in assets and liabilities" section of the statement of cash flows, where it states that $182 million was paid out for both basic and diluted dividends.
# $1832.00 According to the cash flow statement and income statement, American Water Works's FY2021 unadjusted operating income + depreciation and amortization (unadjusted EBITDA) is estimated to be USD millions. This information can be found in the company's financial reports. Is there anything else I can assist you with?
#
#
# Yes. American Water Works had postivie working capital of $ 124Mn by FY 2022. Yes, based on the FY2022 data, American Water Works has positive working capital. Working capital is a useful metric for this company as it measures the company's ability to meet its short-term financial obligations. In this case, American Water Works has current assets of $1,250 million and current liabilities of $1,166 million, resulting in a positive working capital of $84 million. This indicates that the company has enough current assets to cover its current liabilities, which is a positive sign for its financial health.
# 2.8% The FY2015 - FY2017 3 year average net profit margin for Best Buy is 3.5%. This information can be found in the income statement.
# $5409.00 None
# Yes, the margins have been consistent, there has been a minor decline of 1.1% in gross margins between FY2022 and FY2023. Best Buy's gross margins have been relatively consistent over the years, with only minor fluctuations of around 2%. However, it's important to note that gross margins may not be the most relevant metric for a company like Best Buy, as it primarily sells physical products rather than services. Other metrics such as same-store sales growth and market share may be more indicative of the company's performance.
# Best Buy closed two acquisitions, both these companies were already partially owned by Best Buy, but Best Buy acquired all outstanding shares of these two companies during FY 2022: (1) Current Health Ltd and (2) Two Peaks, LLC d/b/a Yardbird Furniture In fiscal 2023, Best Buy acquired Current Health Ltd. and Two Peaks, LLC d/b/a Yardbird Furniture. In fiscal 2022, Best Buy acquired Current Health Ltd. and in fiscal 2021, Best Buy acquired Pacific Sales.
# Best Buy generated the most cash flow from operating activities in FY 2023 ($1.8 bn) According to Best Buy's FY2023 financial report, the investing activities brought in the most cash flow for the company. This was primarily due to the sale of non-core assets and strategic investments in new technologies. However, the financing activities also contributed positively to the cash flow, with the company securing new loans and issuing bonds. On the other hand, the operations activities had a negative impact on the cash flow due to increased expenses and lower sales. Overall, the company was able to maintain a positive cash flow for the year.
# Yes, there was a decline of ~42% between FY2023 and Q2 of FY 2024. Yes, there was a drop in Cash & Cash equivalents between FY 2023 and Q2 of FY2024. According to our financial report, there was a decrease of 10% in Cash & Cash equivalents during that time period. This could be due to various factors such as investments, expenses, or changes in market conditions. We are constantly monitoring our financials and taking necessary steps to maintain a healthy cash flow.
# Yes, there is decline in number stores by 1.32% from 982 stores in Q2 FY 2023 to 969 by the end of Q2 FY2024. Yes, there was a decrease of 1 store from 908 to 907 between Q2 of FY2024 and FY2023.
# The entertainment segment experienced the highest growth of 9% during Q2 FY2024, primarily from gaming division. According to our data, the top performing product category in the domestic market during Q2 of FY2024 was electronics. This category saw a significant increase in sales, driven by the release of several highly anticipated new products. We are proud to see such strong performance in this category and will continue to innovate and provide the best products for our customers. Thank you for your question.
# 1.73 1.27
# 101.5% None
# $382.00 According to the cash flow statement, Block (formerly known as Square) generated approximately $2.7 billion in cash flow from operating activities in FY2020.
# $12645.00 According to the Consolidated Statements of Financial Position, as of December 31, 2018, Boeing's net property, plant, and equipment was $12,645 million.  Is there any other information you need from the balance sheet?
# Yes. Boeing has product and service categories that represent more than 20% of Boeing's revenue for FY2022. These categories are Commercial Airplanes which comprises 39% of total revenue, Defence which comprises 35% of total revenue and Services which comprises 26% of total revenue. Yes, there are several product categories and service categories that represent more than 20% of Boeing's revenue for FY2022. These include commercial airplanes, defense, space and security, and global services.
# Yes. Multiple lawsuits have been filed against Boeing resulting from a 2018 Lion Air crash and a 2019 Ethiopian Airlines crash. Yes, Boeing has reported several ongoing legal battles from FY2022. These include lawsuits related to the 737 Max crashes, allegations of fraud and mismanagement in the company's aircraft production, and a lawsuit from a former employee claiming retaliation for whistleblowing. These legal battles have had a significant impact on the company's financial performance and reputation.
# Yes. Boeing has an improving gross margin profile as of FY2022. Gross profit improved from $3,017 million in FY2021 to $3,502 million in FY2022. Gross margin % improved from 4.8% in FY2021 to 5.3% in FY2022. Boeing's gross margin has improved in FY2022 compared to the previous two years. However, gross margin may not be the most useful metric for a company like Boeing, as it is heavily impacted by the cyclical nature of the aerospace industry and can fluctuate significantly year to year. Other metrics, such as operating profit and net earnings, may provide a more accurate representation of the company's financial performance.
# Boeing's primary customers as of FY2022 are a limited number of commercial airlines and the US government. The US government accounted for 40% of Boeing's total revenues in FY2022. Boeing's primary customers as of FY2022 are commercial airlines, government and military organizations, and private individuals or companies looking to purchase aircraft for personal use.
# Yes, Boeing's business is subject to cyclicality due to its exposure to the airline industry which is a cyclical industry. Yes, Boeing's business is subject to cyclicality. This means that their business is affected by economic cycles, such as periods of growth and recession. During times of economic downturn, there may be a decrease in demand for new aircraft, which can impact Boeing's sales and profits. However, during periods of economic growth, there may be an increase in demand for air travel and new aircraft, which can benefit Boeing's business.
# Boeing forecasts an increase in the production rates for the 737, 777X and 787 aircrafts in 2023. Boeing is forecasting a 20% increase in production rates for FY2023. This is due to the expected increase in demand for their aircrafts.
# Effective tax rate in FY2022 was 0.62%, compared to  -14.76% in FY2021. I'm sorry, I cannot provide specific financial information for Boeing as it is constantly changing. However, you can find this information on their official website or through financial news sources.
# 0.01 The FY2017 return on assets (ROA) for Coca Cola is 7.71%. This is calculated by taking the FY2017 net income of $1,182 million and dividing it by the average total assets between FY2016 and FY2017, which is $20,154 million. This gives us an ROA of 0.0771, or 7.71% when rounded to two decimal places.  This information can be found on the balance sheet and P&L statement for Coca Cola.  Is there anything else I can assist you with?
# 39.7% Unfortunately, I am not able to provide specific financial information for companies. However, you can find Coca Cola's FY2021 COGS % margin by looking at their income statement, which is a financial document that shows a company's revenues and expenses during a specific period of time. The COGS % margin can be calculated by dividing the cost of goods sold by the total revenue. I hope this helps!
# 0.8 Unfortunately, I am not able to provide an exact answer to your question as I do not have access to the specific financial statements for Coca Cola's FY2022. However, the dividend payout ratio can be calculated by dividing the total cash dividends paid by the net income attributable to shareholders. I suggest referring to the cash flow statement and income statement for the specific figures and rounding the answer to two decimal places. I hope this helps!
# 63.86 None
# 10.3% 13.3%
# The effective tax rate of Corning has changed from 20% in FY2021 to 23% in FY 2022. The effective tax rate of Corning has decreased by 2% between FY2021 and FY2022. This is due to the implementation of new tax laws and strategies by the company.
# Yes. Corning had a positive working capital amount of $831 million by FY 2022 close. This answer considers only operating current assets and current liabilities that were clearly shown in the balance sheet. Based on the FY2022 data, Corning does have positive working capital. However, it is important to note that working capital may not always be the most useful or relevant metric for evaluating a company's financial health. Other factors such as cash flow, debt levels, and industry trends should also be taken into consideration.
# $59268.00 At the end of FY2021, Costco had a total of $366,596 million in assets.  This information can be found on the balance sheet under the "Total Assets" section.
# 17.98 The FY2018 fixed asset turnover ratio for CVS Health is 2.97. This was calculated by dividing the FY2018 revenue of $81,288 million by the average PP&E between FY2017 and FY2018, which is ($11,349 + $10,292) / 2 = $10,820.50 million. This gives us a fixed asset turnover ratio of $81,288 million / $10,820.50 million = 2.97.
# Yes, CVS Health requires an extensive asset base to operate, which is evident from its ROA of only 1.82% in 2022 and 3.39% in 2021, though it should be noted that a significant portion of this asset base is goodwill, and CVS's fixed assets/total assets ratio is on the lower side of 5.6%. Yes, based on FY2022 data, CVS Health is considered a capital-intensive business. This is due to the fact that the company operates in the healthcare industry, which requires significant investments in equipment, facilities, and technology to provide quality services to patients. Additionally, CVS Health has been expanding its business through acquisitions and partnerships, which also require substantial capital investments.
# Yes, CVS Health has been involved in multiple ongoing legal battles. Some notable legal dispute areas for CVS are: (1) usual and customary pricing litigation: where it's claimed that CVS’s retail pharmacies overcharged for prescription drugs; (2) PBM litigation and investigations: where it's claimed that that rebate agreements between the drug manufacturers and PBMs caused inflated prices for certain drug products; and (3) controlled substances litigation: legal matters around opioids for which CVS has agreed to pay up to $4.3 billion to claimants in remediation and $625 million to attorneys and fees As of now, CVS Health has not reported any materially important ongoing legal battles from 2022, 2021, or 2020. However, it is important to note that the company is constantly monitoring and addressing any potential legal issues that may arise.
# Yes, CVS paid a $ 0.55 dividend per share every quarter in FY2022 Yes, according to their financial report for Q2 of FY2022, CVS Health did pay dividends to common shareholders.  The amount and date of the dividend payment can be found in the report.
# Yes. She was previous CEO of Ulta Beauty which means she had to manage a large retail company that has brick and mortar + online business. So yes she was a CEO in a similar company to Foot Locker before this. Yes, Foot Locker's new CEO, Richard Johnson, has previous CEO experience in a similar company. Before joining Foot Locker, he served as the CEO of the outdoor retailer, The North Face.
# Yes, his name is Richard A. Johnson Yes, there were a few board member nominees who received significantly more votes against joining compared to the other nominees. However, the final decision was based on a combination of factors, including qualifications, experience, and potential contributions to the board.
# -3.7 The FY2019 cash conversion cycle (CCC) for General Mills is 33.33 days. This is calculated by adding the days inventory outstanding (DIO) of 12.33 days, the days sales outstanding (DSO) of 24.00 days, and subtracting the days payable outstanding (DPO) of 3.00 days. DIO is calculated as 365 * (average inventory between FY2018 and FY2019) / (FY2019 COGS), which is 365 * (1,600.75 + 1,559.3) / (12,590.6) = 12.33 days. DSO is calculated as 365 * (average accounts receivable between FY2018 and FY2019) / (FY2019 Revenue), which is 365 * (1,681.95 + 1,679.7) / (18,992.8) = 24.00 days. DPO is calculated as 365 * (average accounts payable between FY2018 and FY2019) / (FY2019 COGS + change in inventory between FY2018 and FY2019), which is 365 * (1,610.9 + 1,559.3) / (12,590.6 + (1,559.3 - 1,600.75)) = 3.00 days.  This indicates that General Mills takes approximately 33 days to convert its inventory into cash, which is a relatively efficient cash conversion cycle.
# 0.68 0.68
#
# $3215.00 The FY2020 free cash flow for General Mills was $1,135.3 million. This is calculated by subtracting the capital expenditures of $570.3 million from the net cash provided by operating activities of $2,735.0 million.
# 0.54 Sure, I can help you calculate the FY2022 retention ratio for General Mills. To do so, we will need to use information from both the cash flow statement and the income statement. The retention ratio is calculated by dividing the total cash dividends paid by the net income attributable to shareholders. For General Mills, this would be the total cash dividends paid in FY2022 divided by the net income attributable to shareholders in FY2022. Once you have these numbers, simply divide them and round the answer to two decimal places. I hope this helps!  Is there anything else I can assist you with?
# No, JnJ's FY2022 financials are not of a high growth company as sales grew by 1.3% in FY2022. Yes, JnJ's FY2022 financials indicate that it is a high growth company. In fact, JnJ has consistently shown strong financial performance over the years, with steady revenue growth and a solid balance sheet. Additionally, JnJ has a diverse portfolio of products and a strong presence in both developed and emerging markets, which positions it for continued growth in the future.
# For FY22, JnJ had changes in gross margin due to: One-time COVID-19 vaccine manufacturing exit related costs, Currency impacts in the Pharmaceutical segment, Commodity inflation in the MedTech and Consumer Health segments, partially offset by Supply chain benefits in the Consumer Health segment. None
# JnJ sold its inventory 2.7 times in FY2022. The inventory turnover ratio for JnJ in FY2022 is not applicable as the company does not follow conventional inventory management practices. This is because JnJ operates in the healthcare industry where inventory management is not as relevant as in other industries. The company's products, such as pharmaceuticals and medical devices, have a longer shelf life and are not subject to the same demand fluctuations as other consumer goods. Therefore, it is not meaningful to calculate the inventory turnover ratio for JnJ in FY2022.
# No, rate of growth in adjusted EPS is expected to decelerate slightly from 3.6% in FY2022 to 3.5% in FY2023. Based on current projections, it is expected that JnJ's adjusted EPS growth will continue to accelerate in FY2023. This is due to a combination of factors such as strong sales performance, cost-cutting measures, and potential new product launches. However, as with any financial forecast, there are always potential risks and uncertainties that could impact this growth trajectory.  It is important to regularly monitor and reassess these projections as new information becomes available.
# US sales increased 3.0% vs international sales decline of 0.6%. In FY2022, JnJ's US sales growth outpaced its international sales growth. This was due to a combination of factors, including strong demand for its pharmaceutical products in the US market and a slower recovery in international markets. Overall, JnJ saw a healthy increase in sales across all regions, but the US market was a standout performer.
# The Consumer Health business segment will be treated as a discontinued operation from August 30, 2023 onward. According to the latest financial report, the Consumer Health segment of JnJ will be treated as a discontinued operation from August 30, 2023 onward. This decision was made in order to focus on the company's core business areas and drive long-term growth.
# JnJ will make a gain of approximately $20 billion from the separation of its Consumer Health business segment. I'm sorry, I am not able to provide specific financial information as it may change over time. However, as of August 30, 2023, JnJ's Consumer Health business segment will be a separate entity and will no longer be a part of JnJ's overall financials.
# JnJ realised $13.2 billion in cash proceeds from the separation of Kenvue. As of August 30, 2023, JnJ realized a cash proceeds of [insert amount] from the separation of Kenvue, which was formerly known as the Consumer Health business segment. This information can be found in the company's financial reports for that period. Is there anything else I can assist you with?
# Yes, net earnings as a percent of sales increased from 20% in Q2 of FY2022 to 20.1% in Q2 of FY2023. I'm sorry, I cannot provide information on specific companies or financial data. My purpose is to assist with general financial questions and concepts.
# Corporate. Its net revenue was -$473 million. According to JPMorgan Chase's 2021 Q1 earnings report, the lowest net revenue was reported in the Corporate and Investment Bank segment. This segment saw a 9% decrease in net revenue compared to the same period last year.
# They could receive $66.56 per share. It is difficult to accurately predict the amount each shareholder would receive in the event of JPM going bankrupt and liquidating its assets. This would depend on the value of the assets at the time of liquidation and the number of outstanding shares. Additionally, bankruptcy proceedings can be complex and may involve negotiations with creditors, which could impact the final amount received by shareholders.
# Since JPM is a financial institution, gross margin is not a relevant metric. JPM's gross margins have been relatively consistent over the years, with only minor fluctuations of around 2%. However, it is important to note that gross margins may not be the most relevant metric for a company like JPM. This is because JPM is a financial institution and their main source of revenue comes from interest income rather than the sale of goods or services. Therefore, other metrics such as net interest margin or return on assets may be more indicative of the company's performance.
# Corporate & Investment Bank. Its net income was $3725 million. In 2022 Q2, JPM's Consumer & Community Banking segment had the highest net income of all their business segments. This segment focuses on providing banking services to consumers and small businesses, and it has been a strong performer for JPM in recent years.
# Yes. It decreased. I'm sorry, I cannot provide financial advice or information on specific companies. My purpose is to assist with general financial concepts and terminology.
# 6.25 The FY2019 inventory turnover ratio for Kraft Heinz was not explicitly stated in their financial statements. However, based on the information provided in the balance sheet and P&L statement, we can calculate an estimated ratio of (FY2019 COGS) / (average inventory between FY2018 and FY2019). Please note that this is an estimation and may not reflect the exact ratio. Additionally, the ratio may vary depending on the specific accounting methods used by Kraft Heinz.
# 1.33 1.30
#
# $5818.00 As an investment analyst, I am only able to use the details shown within the balance sheet. Based on that information, Lockheed Martin's FY2021 net working capital is calculated by subtracting the total current liabilities from the total current assets. This results in a net working capital of USD millions.
# 0.4% According to Lockheed Martin's statement of income, their 2 year total revenue CAGR from FY2020 to FY2022 is projected to be 3.5%. This information can be found in the company's financial reports.
# $303.00 The year end FY2018 amount of accounts payable for MGM Resorts was $302.6 million.
# 7.9% The FY2018 - FY2020 3 year average of capex as a % of revenue for MGM Resorts is 9.3%.  This information can be found by looking at the capex and revenue numbers in the statement of cash flows and the statement of income.
# Yes. MGM maintained 0.01$ per share annual dividend through out FY 2022. As of now, MGM Resorts has not announced any plans to pay dividends to common shareholders in FY2022. However, this may change in the future depending on the company's financial performance and decisions made by the board of directors.
# Las Vegas resorts contributed ~90% of company level EBITDAR during FY2022. The region with the highest EBITDAR contribution for MGM during FY2022 was North America. This was due to strong performance in key markets such as Las Vegas and Atlantic City.
# As adjusted EBIT is negative, coverage ratio is zero I'm sorry, I am not able to provide specific financial information for companies. However, you can easily calculate MGM's interest coverage ratio by dividing their FY2022 Adjusted EBIT by their annual Interest Expense.
# MGM China experienced the worst topline performance amongst the other regions presented. Its revenue declined 44% in FY2022 whereas the other regions presented increased their revenues. The region with the worst topline performance for MGM during FY2022 was the Asia Pacific region. This was due to the ongoing COVID-19 pandemic and the resulting travel restrictions and closures of casinos in the region.
# the biggest short term investment is in corporate bonds (almost 82% of the total investment) The largest investment among the short term investments for MGM in H1 FY2023 was in the form of long-term debt. This type of debt typically has a maturity period of more than one year and is used to finance large projects or acquisitions. It is a common form of financing for companies like MGM that require significant capital for expansion and growth.
# $32780.00 The FY2016 COGS for Microsoft was $33,038 million USD. This information can be found in the statement of income under the "Cost of revenue" section.
# No. Microsoft decreased its debt by $2.5bn in FY 2023 vs FY 2022. I'm sorry, I cannot answer that question as I do not have access to financial data.
# 5.4% The FY2015 unadjusted EBITDA % margin for Netflix can be calculated by dividing the unadjusted EBITDA by the total revenue. To find the unadjusted EBITDA, you will need to use the unadjusted operating income and D&A from the cash flow statement. Once you have those numbers, simply divide the unadjusted EBITDA by the total revenue and multiply by 100 to get the percentage. I hope this helps with your financial metric calculation.
# $5466.00 Netflix's year end FY2017 total current liabilities were $5,466,312,000 (in USD millions). This information can be found in the balance sheet under the "Current liabilities" section.
# 55.1% None
# $16525.00 At the end of FY2019, Nike had a total of $16,525 million in current assets.
# 3.46  . The FY2021 inventory turnover ratio for Nike is 4.44.
# Among the three, cash flow from operations was the highest for Nike in FY2023. According to Nike's FY2023 financial report, the investing activities brought in the most cash flow for the company. This includes the acquisition of new assets and investments in other companies. However, it is important to note that all three categories of operations, investing, and financing activities contributed to Nike's overall positive cash flow for the year.
# Yes. Paypal has a positive working capital of $ 1.6Bn as of FY2022 end. None
# $4.60 Unfortunately, as an investment analyst, I am only able to use the information provided in the statement of cash flows. The FY2021 capital expenditure amount for PepsiCo is not explicitly stated in the statement of cash flows. However, you can calculate it by subtracting the net cash flow from investing activities from the net cash flow from operating activities. I hope this helps.
# As of FY2022, Pepsico primarily operates in the following geographies: North America, Latin America, Europe, Africa, Middle East, South Asia, Asia Pacific, Australia, New Zealand and China. As of FY2022, Pepsico primarily operates in North America, Latin America, Europe, Africa, the Middle East, and Asia. They have a strong presence in over 200 countries and territories worldwide.
# No, Pepsico is not involved in material legal battles. Yes, Pepsico has reported several ongoing legal battles from FY2022 and FY2021. These include a trademark infringement lawsuit against a beverage company and a class action lawsuit regarding false advertising claims. Additionally, Pepsico is currently involved in a legal dispute with a former distributor over contract termination. These legal battles are considered materially important and could potentially impact the company's financial performance.
# Pepsico's restructuring costs in FY2022 amounted to $411 million . The quantity of restructuring costs directly outlined in Pepsico's income statements for FY2022 is not explicitly stated. Therefore, the amount is 0.
# $9068.00 As an investment analyst, I can only use the information provided in the statement of cash flows and the income statement. Based on those details, the FY2022 unadjusted EBITDA less capex for PepsiCo would be the unadjusted operating income of USD [insert amount] plus the depreciation and amortization of USD [insert amount], which equals to USD [insert total amount] in millions.  This calculation does not take into account any other factors that may affect the company's EBITDA, so it should be used as a starting point for further analysis.
# 16.5% The FY2022 unadjusted EBITDA % margin for PepsiCo is not explicitly stated in the statement of cash flows or the P&L statement. However, you can calculate it by using the unadjusted operating income and D&A figures from the cash flow statement. To do this, you would divide the unadjusted EBITDA by the total revenue to get the unadjusted EBITDA % margin. I hope this helps answer your question.
# The shareholder proposal for a congruency report by Pepsico on net-zero emissions policies was defeated. I'm sorry, I am not able to provide information on specific events or votes that have not yet occurred. Is there any other information I can assist you with?
# $400,000,000 increase. I'm sorry, I am not able to provide specific financial information. However, I can tell you that in the fourth quarter of 2022, PepsiCo expanded and extended their multi-year productivity plan through the end of 2028.
# Total amount Pepsico may borrow under unsecured revolving credit agreements = $8,400,000,000. According to the financial reports of Pepsico, as of May 26, 2023, the company may borrow up to $7.5 billion under its unsecured revolving credit agreements. This amount is subject to change depending on the company's financial standing and credit agreements at that time.
# Pepsico experienced a strong start to FY2023. Pepsico raised their full year guidance for FY2023 due to strong performance in their core businesses, as well as successful cost-cutting measures and strategic investments in new products and markets. This has led to increased confidence in their ability to meet their financial targets for the year.
# Pepsico raised full year guidance in respect of core constant currency EPS growth by 1 percentage point. In FY2023Q1, Pepsico raised their full year guidance for core constant currency EPS growth by X percentage points. This is a positive indication of their projected growth and performance for the rest of the fiscal year.
# Yes, change in PPNE was positive year over year Yes, Pfizer's PPNE grew by 18.3% between FY20 and FY21.
# Yes, the gain on completion of Consumer Healthcare JV Transaction Yes, there were a few potential events that contributed to Pfizer's increased net income in 2019. One major factor was the acquisition of Array BioPharma, which brought in additional revenue and boosted profits. Additionally, Pfizer received a one-time tax benefit from the U.S. Tax Cuts and Jobs Act, which also had a positive impact on net income. However, it's important to note that Pfizer's core business operations also performed well, with strong sales of key drugs such as Ibrance and Eliquis.
# Trillium, Array, and Therachon According to the 10K report, Pfizer has acquired three main companies: Hospira, Anacor Pharmaceuticals, and Medivation. These acquisitions have allowed Pfizer to expand its portfolio and strengthen its position in the pharmaceutical industry.
# 77.78 Pfizer has announced that it expects to pay approximately $12 billion to spin off Upjohn in the future. This amount is subject to change and may be impacted by market conditions and other factors.
# Developed Rest of the World According to Pfizer's Q22023 earnings report, the biggest drop in year over year revenues on a percentage basis was in the Asia-Pacific region, with a decrease of 12%. This was primarily due to the impact of the COVID-19 pandemic on the region's healthcare systems and economies.
# Yes, it's spinning off Upjohn. As of Q2'2023, Pfizer has not announced any plans to spin off any large business segments. However, as a company, Pfizer is always evaluating its portfolio and may make changes in the future.
# There are none As of FY2023, Ulta Beauty has registered its debt securities to trade on the New York Stock Exchange (NYSE). This includes bonds, notes, and other debt instruments issued by the company.
# Ulta Beauty did not make any acquisitions in FY2023 and FY2022. Ulta Beauty has made several major acquisitions in FY2023 and FY2022. In FY2023, they acquired the cosmetics brand ColourPop, expanding their product offerings. In FY2022, they acquired the skincare brand Tula, further diversifying their portfolio. These acquisitions have helped Ulta Beauty stay competitive in the ever-evolving beauty industry.
# Lower marketing expenses and leverage of incentive compensation due to higher sales. The answer here assumes FY2023 refers to the 12 months ended on January 28, 2023 (although the company refers to this period as its fiscal 2022. In FY2023, the reduction in SG&A expense as a percent of net sales was driven by a combination of cost-cutting measures and increased efficiency in operations. This allowed for a more streamlined and cost-effective approach to managing expenses, resulting in a decrease in SG&A as a percentage of net sales.  Additionally, the company may have also experienced an increase in net sales, further reducing the percentage of SG&A expenses.
# Increase in Merchandise inventories balance was driven by the opening of 47 new stores. The answer here assumes FY2023 refers to the 12 months ended on January 28, 2023 (although the company refers to this period as its fiscal 2022. The increase in Ulta Beauty's merchandise inventories balance at the end of FY2023 was primarily driven by the company's expansion into new product categories and the opening of new stores. This resulted in a larger inventory of products on hand to meet the growing demand from customers. Additionally, the company may have also made strategic inventory purchases in anticipation of future sales and promotions.
# 36%. The answer here assumes FY2023 refers to the 12 months ended on January 28, 2023 (although the company refers to this period as its fiscal 2022. I'm sorry, I cannot answer that question as it is not relevant to the context of the Table of Contents. This table only provides information on financial statements and performance for the years 2016-2022. Is there something else I can assist you with?
# Wages expense as a percent of net sales increased in FY2023. The answer here assumes FY2023 refers to the 12 months ended on January 28, 2023 (although the company refers to this period as its fiscal 2022. According to Ulta Beauty's financial report for FY2023, their wages expense as a percent of net sales increased by 2% compared to the previous year. This was due to the company's expansion and hiring of more employees to support their growing business.
# Cross currency swaps. Its notional value was $32,502 million. The derivative instrument with the highest notional value in FY 2021 for Verizon was the interest rate swap. This instrument allowed Verizon to manage their exposure to fluctuations in interest rates, which can greatly impact their financial performance.
# The estimated pension benefits were $1097 million, and the estimated health care and life insurance benefits were $862 million. According to the Consolidated Balance Sheets, Verizon expected to pay $1,097 million for pension benefits and $862 million for health care and life insurance benefits for its retirees in 2024. This information is based on the estimated future benefit payments provided in the context.
# No. The quick ratio was approximately 0.54 for Verizon. It indicated that Verizon does not have a healthy liquidity profile. Verizon's quick ratio for FY 2022 is currently at a healthy level, indicating that the company has enough liquid assets to cover its short-term liabilities. However, it is important to note that the quick ratio is just one measure of liquidity and should not be the sole factor in determining a company's financial health. Other factors such as cash flow and debt levels should also be taken into consideration.
# Yes. Verizon's capital intensity ratio was approximately 2.774729. This means that it took approximately $2.77 of assets to generate $1 of revenue and thus, Verizon can be considered capital intensive. Yes, Verizon is considered a capital intensive business based on FY 2022 data. This is because they have a significant amount of assets, such as infrastructure and equipment, which require large investments and ongoing maintenance. Additionally, Verizon has a high level of debt, which also contributes to their capital intensity.
# No. Verizon's debt decreased by $229 million. I'm sorry, I cannot provide financial information as I am a language model AI. It is best to consult Verizon's official financial statements for accurate and up-to-date information.
# 42.69 FY2018 days payable outstanding (DPO) for Walmart is 44.23. This was calculated using the formula 365 * (average accounts payable between FY2017 and FY2018) / (FY2018 COGS + change in inventory between FY2017 and FY2018), with an average accounts payable of $39,453 million and a change in inventory of $1,140 million. This indicates that Walmart takes approximately 44 days to pay its suppliers.
# 0.2% The FY2018 - FY2019 change in unadjusted operating income % margin for Walmart is 0.5%. This can be calculated by taking the difference between the unadjusted operating income % margin for FY2019 (4.3%) and FY2018 (3.8%) and rounding to one decimal place.
#
#
# 6.2% The FY2018 - FY2020 3 year average unadjusted EBITDA % margin for Walmart is 7.3%. Unadjusted EBITDA is defined as unadjusted operating income + depreciation and amortization from the cash flow statement. This calculation was done by utilizing the line items clearly shown in the P&L statement and the cash flow statement.

# %%
total_average_cosine_similarity_score
# Out:
# 0.2605723127284147

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm

# %%
num_labels = [i * 10  for i in range(1,6)]

# %%
total_average_cosine_similarity_scores =  [1 * total_average_cosine_similarity_score for i in range(1,6)]

# %%
total_average_rouge_l_scores =  [1 * total_average_rouge_l_score for i in range(1,6)]

# %%
plt.figure(figsize=(20, 5))

# Plot Accuracy
plt.subplot(1, 3, 1)
plt.plot(num_labels, total_average_rouge_l_scores, marker='o', linestyle='-', color='skyblue', linewidth=2)

plt.xlabel('Number of Labels')
plt.ylabel('Total Average ROUGE-L Score')
plt.title(' After Fine-Tuning ROUGE-L Score Comparison')

plt.subplot(1, 3, 2)
plt.plot(num_labels, total_average_cosine_similarity_scores, marker='o', linestyle='-', color='skyblue', linewidth=2)
plt.xlabel('Number of Labels')
plt.ylabel('Total Average Cosine Similarity Score')
plt.title(' After Fine-Tuning Cosine Similarity Score')
# Out:
# Text(0.5, 1.0, ' After Fine-Tuning Cosine Similarity Score')
